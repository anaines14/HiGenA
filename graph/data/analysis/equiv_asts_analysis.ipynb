# %% [markdown]
# # AST Equivalency Analysis

# %% [markdown]
# Import data.

# %%
import pandas as pd

def importData(file):
    # Import data
    data = pd.read_csv(file)
    return data

df = importData('uniqueASTs.csv')
df
# Out:
#                                                   AST  \
# 0                                              {true}
# 1   {all{one of{this/File}}{historically{!in{var/t...
# 2   {all{one of{this/File}}{in{var/this/File}{this...
# 3   {all{one of{this/File}}{AND{!in{var/this/File}...
# 4    {always{AND{no{this/File}}{no{this/Protected}}}}
# 5   {always{before{all{one of{this/File}}{in{var/t...
# 6   {always{AND{no{this/Trash}}{no{this/Protected}}}}
# 7   {before{all{one of{this/File}}{in{var/this/Fil...
# 8         {before{no{+{this/Trash}{this/Protected}}}}
# 9   {AND{before{no{this/Trash}}}{no{this/Protected}}}
# 10  {before{AND{no{this/Trash}}{no{this/Protected}}}}
# 11                           {before{no{this/Trash}}}
# 12  {historically{AND{no{this/Trash}}{no{this/Prot...
# 13  {AND{historically{AND{no{this/Trash}}{no{this/...
# 14  {historically{once{no{&{this/Trash}{this/Prote...
# 15  {historically{once{no{+{this/Trash}{this/Prote...
# ...

# %% [markdown]
# Check similar ASTs.

# %%
equiv = df.iloc[[24, 28]]
equiv
# Out:
#                                           AST                       Expr
# 24  {AND{no{this/Protected}}{no{this/Trash}}}      no Protected no Trash
# 28  {AND{no{this/Trash}}{no{this/Protected}}}  no Trash and no Protected
