# %% [markdown]
# # Import data

# %%
import os
import pandas as pd
import collections
import seaborn as sns
import re
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth', None)

# %%
def importCsvs(path, type="csv"):
    # Import the csv files
    # path: path to the csv files
    # return: dictionary of dataframes for each challenge and each predicate

    allDfs = {} # Dictionary of dataframes for each challenge and each predicate

    # Iterate over the folders
    for folder in os.listdir(path):
        # Iterate over the csv files
        for file in os.listdir(path + folder):
            # Read the file
            if type == "csv":
                df = pd.read_csv(path + folder + "/" + file)
            elif type == "json":
                df = pd.read_json(path + folder + "/" + file, lines=True)
            else:
                print("Error: unknown file type")
                return
            # Add the dataframe to the dictionary
            if folder not in allDfs:
                allDfs[folder] = {}
            cmd = re.sub("\..*", "", file)
            allDfs[folder][cmd] = df
            
        

    return allDfs

# Import the csv files
allDfs = importCsvs("../all/")
trainDfs = importCsvs("../train/")
testDfs = importCsvs("../test/", "json")

# %% [markdown]
# # Data analysis

# %% [markdown]
# Count number of submissions, correct and incorrect.

# %%
def analyzeData(allDfs):
    analysisDf = pd.DataFrame({"Challenge": [], "Predicate": [], "NumSubmissions": [], "NumCorrect": [], "NumIncorrect": []})
    counter = collections.Counter()

    for challenge, cmdDfs in allDfs.items():
        for cmd, df in cmdDfs.items():
        # Update counter
            count = df["sat"].value_counts().to_dict()
            counter.update(count)
            analysisDf.loc[len(analysisDf)] = [
                challenge,
                cmd,
                len(df),
                len(df[df["sat"] == 0.0]),
                len(df[df["sat"] == 1.0])
            ]

    # Sort by number of submissions
    analysisDf = analysisDf.sort_values(by=['NumSubmissions'], ascending=False)

    print("Total number of submissions: " + str(analysisDf["NumSubmissions"].sum()))
    print("Total number of correct submissions: " + str(analysisDf["NumCorrect"].sum()))
    print("Total number of incorrect submissions: " + str(analysisDf["NumIncorrect"].sum()))

    # Show plot    
    sns.barplot(data=pd.DataFrame.from_dict(counter, orient="index").reset_index(), x="index", y=0, palette=["green", "red"])

    return analysisDf

# %% [markdown]
# ## Analyze all submissions

# %%
analyzeData(allDfs)
# Out:
# Total number of submissions: 24278
# Total number of correct submissions: 10636
# Total number of incorrect submissions: 13642
#              Challenge         Predicate  NumSubmissions  NumCorrect  \
# 80   YH3ANm7Y5Qe5dSYem             inv11             598          78
# 83   YH3ANm7Y5Qe5dSYem             inv14             544          57
# 45   gAeD3MTGCCv8YNTaK   weaklyConnected             531          78
# 96   zoEADeCW2b2suJB2k              inv4             529          70
# 15   9jPK8KBWzjFmBx4Hb             prop5             424          65
# 81   YH3ANm7Y5Qe5dSYem             inv12             420          61
# 44   gAeD3MTGCCv8YNTaK        undirected             412         209
# 3    9jPK8KBWzjFmBx4Hb            prop12             409          37
# 16   9jPK8KBWzjFmBx4Hb             prop6             386         119
# 71   sDLK7uBCbgZon3znd              inv7             380         157
# 102  zRAn69AocpkmxXZnW             inv11             378          83
# 61   PQAJE67kz8w5NWJuM              inv7             374         135
# 95   zoEADeCW2b2suJB2k              inv3             368         108
# 114  zRAn69AocpkmxXZnW              inv9             367         113
# 64   sDLK7uBCbgZon3znd              inv1             355         316
# 60   PQAJE67kz8w5NWJuM              inv6             351         172
# 1    9jPK8KBWzjFmBx4Hb            prop10             349          54
# 101  zRAn69AocpkmxXZnW             inv10             342         115
# 18   9jPK8KBWzjFmBx4Hb             prop8             336          57
# 59   PQAJE67kz8w5NWJuM              inv5             319         153
# 106  zRAn69AocpkmxXZnW             inv15             314          45
# 39   gAeD3MTGCCv8YNTaK          complete             303         135
# 110  zRAn69AocpkmxXZnW              inv5             299         131
# 49   JC8Tij8o8GZb99gEJ              Inv4             299           1
# 54   PQAJE67kz8w5NWJuM              inv1             289         261
# 70   sDLK7uBCbgZon3znd              inv6             287         168
# 105  zRAn69AocpkmxXZnW             inv14             280          40
# 109  zRAn69AocpkmxXZnW              inv4             278         151
# 112  zRAn69AocpkmxXZnW              inv7             275         130
# 88   YH3ANm7Y5Qe5dSYem              inv5             264         139
# 97   zoEADeCW2b2suJB2k              inv5             263          59
# 87   YH3ANm7Y5Qe5dSYem              inv4             262         146
# 41   gAeD3MTGCCv8YNTaK          oriented             260         145
# 55   PQAJE67kz8w5NWJuM             inv10             253         125
# 111  zRAn69AocpkmxXZnW              inv6             247         140
# 63   PQAJE67kz8w5NWJuM              inv9             245         136
# 9    9jPK8KBWzjFmBx4Hb            prop18             241          46
# 69   sDLK7uBCbgZon3znd              inv5             237         167
# 93   zoEADeCW2b2suJB2k              inv1             237         147
# 99   zoEADeCW2b2suJB2k              inv7             236          11
# 14   9jPK8KBWzjFmBx4Hb             prop4             236         108
# 84   YH3ANm7Y5Qe5dSYem             inv15             235          44
# 86   YH3ANm7Y5Qe5dSYem              inv3             234         171
# 58   PQAJE67kz8w5NWJuM              inv4             233         158
# 91   YH3ANm7Y5Qe5dSYem              inv8             233         138
# 100  zRAn69AocpkmxXZnW              inv1             231         211
# 92   YH3ANm7Y5Qe5dSYem              inv9             230         125
# 38   gAeD3MTGCCv8YNTaK           acyclic             228         136
# 11   9jPK8KBWzjFmBx4Hb             prop2             227          83
# 113  zRAn69AocpkmxXZnW              inv8             226         130
# 65   sDLK7uBCbgZon3znd             inv10             221         127
# 78   YH3ANm7Y5Qe5dSYem              inv1             218         204
# 68   sDLK7uBCbgZon3znd              inv4             216         172
# 2    9jPK8KBWzjFmBx4Hb            prop11             216          82
# 103  zRAn69AocpkmxXZnW             inv12             212          69
# 82   YH3ANm7Y5Qe5dSYem             inv13             212          97
# 42   gAeD3MTGCCv8YNTaK  stonglyConnected             209          96
# 40   gAeD3MTGCCv8YNTaK           noLoops             209         124
# 66   sDLK7uBCbgZon3znd              inv2             206         183
# 56   PQAJE67kz8w5NWJuM              inv2             201         158
# 48   JC8Tij8o8GZb99gEJ              Inv3             193          26
# 108  zRAn69AocpkmxXZnW              inv3             189         138
# 104  zRAn69AocpkmxXZnW             inv13             188          93
# 31   FwCGymHmbqcziisH5             prop3             188          38
# 57   PQAJE67kz8w5NWJuM              inv3             187         152
# 79   YH3ANm7Y5Qe5dSYem             inv10             182         143
# 73   sDLK7uBCbgZon3znd              inv9             182         150
# 72   sDLK7uBCbgZon3znd              inv8             181         171
# 19   9jPK8KBWzjFmBx4Hb             prop9             179          89
# 67   sDLK7uBCbgZon3znd              inv3             176         166
# 53   jyS8Bmceejj9pLbTW              Inv4             166          41
# 89   YH3ANm7Y5Qe5dSYem              inv6             165         131
# 94   zoEADeCW2b2suJB2k              inv2             164         122
# 62   PQAJE67kz8w5NWJuM              inv8             163         156
# 5    9jPK8KBWzjFmBx4Hb            prop14             162          67
# 90   YH3ANm7Y5Qe5dSYem              inv7             162         123
# 77   WGdhwKZnCu7aKhXq9              Inv4             157          18
# 0    9jPK8KBWzjFmBx4Hb             prop1             153         126
# 51   jyS8Bmceejj9pLbTW              Inv2             153          57
# 46   JC8Tij8o8GZb99gEJ              Inv1             152          76
# 17   9jPK8KBWzjFmBx4Hb             prop7             151          97
# 85   YH3ANm7Y5Qe5dSYem              inv2             150         145
# 8    9jPK8KBWzjFmBx4Hb            prop17             148          48
# 7    9jPK8KBWzjFmBx4Hb            prop16             147          51
# 107  zRAn69AocpkmxXZnW              inv2             143         133
# 47   JC8Tij8o8GZb99gEJ              Inv2             141          52
# 43   gAeD3MTGCCv8YNTaK        transitive             141          89
# 12   9jPK8KBWzjFmBx4Hb            prop20             135          54
# 50   jyS8Bmceejj9pLbTW              Inv1             124          76
# 33   FwCGymHmbqcziisH5             prop5             124           1
# 4    9jPK8KBWzjFmBx4Hb            prop13             121          82
# 13   9jPK8KBWzjFmBx4Hb             prop3             112         100
# 10   9jPK8KBWzjFmBx4Hb            prop19             110          45
# 98   zoEADeCW2b2suJB2k              inv6             110          77
# 30   FwCGymHmbqcziisH5             prop2             106          41
# 6    9jPK8KBWzjFmBx4Hb            prop15             101          50
# 52   jyS8Bmceejj9pLbTW              Inv3              94          63
# 20   FwCGymHmbqcziisH5             prop1              92          46
# 32   FwCGymHmbqcziisH5             prop4              90          29
# 34   FwCGymHmbqcziisH5             prop6              84           4
# 37   FwCGymHmbqcziisH5             prop9              84           1
# 76   WGdhwKZnCu7aKhXq9              Inv3              57          11
# 75   WGdhwKZnCu7aKhXq9              Inv2              45          19
# 35   FwCGymHmbqcziisH5             prop7              43           9
# 26   FwCGymHmbqcziisH5            prop15              36           4
# 36   FwCGymHmbqcziisH5             prop8              35           3
# 74   WGdhwKZnCu7aKhXq9              Inv1              29          20
# 25   FwCGymHmbqcziisH5            prop14              28           1
# 22   FwCGymHmbqcziisH5            prop11              25           8
# 28   FwCGymHmbqcziisH5            prop17              16           1
# 24   FwCGymHmbqcziisH5            prop13              14           3
# 21   FwCGymHmbqcziisH5            prop10              13          10
# 27   FwCGymHmbqcziisH5            prop16               9           2
# 23   FwCGymHmbqcziisH5            prop12               2           1
# 29   FwCGymHmbqcziisH5            prop18               2           1
#
#      NumIncorrect
# 80            520
# 83            487
# 45            453
# 96            459
# 15            359
# 81            359
# 44            203
# 3             372
# 16            267
# 71            223
# 102           295
# 61            239
# 95            260
# 114           254
# 64             39
# 60            179
# 1             295
# 101           227
# 18            279
# 59            166
# 106           269
# 39            168
# 110           168
# 49            298
# 54             28
# 70            119
# 105           240
# 109           127
# 112           145
# 88            125
# 97            204
# 87            116
# 41            115
# 55            128
# 111           107
# 63            109
# 9             195
# 69             70
# 93             90
# 99            225
# 14            128
# 84            191
# 86             63
# 58             75
# 91             95
# 100            20
# 92            105
# 38             92
# 11            144
# 113            96
# 65             94
# 78             14
# 68             44
# 2             134
# 103           143
# 82            115
# 42            113
# 40             85
# 66             23
# 56             43
# 48            167
# 108            51
# 104            95
# 31            150
# 57             35
# 79             39
# 73             32
# 72             10
# 19             90
# 67             10
# 53            125
# 89             34
# 94             42
# 62              7
# 5              95
# 90             39
# 77            139
# 0              27
# 51             96
# 46             76
# 17             54
# 85              5
# 8             100
# 7              96
# 107            10
# 47             89
# 43             52
# 12             81
# 50             48
# 33            123
# 4              39
# 13             12
# 10             65
# 98             33
# 30             65
# 6              51
# 52             31
# 20             46
# 32             61
# 34             80
# 37             83
# 76             46
# 75             26
# 35             34
# 26             32
# 36             32
# 74              9
# 25             27
# 22             17
# 28             15
# 24             11
# 21              3
# 27              7
# 23              1
# 29              1

# %% [markdown]
# ## Analyze train data

# %%
analyzeData(trainDfs)
# Out:
# Total number of submissions: 21231
# Total number of correct submissions: 9321
# Total number of incorrect submissions: 11910
#              Challenge         Predicate  NumSubmissions  NumCorrect  \
# 80   YH3ANm7Y5Qe5dSYem             inv11             523          59
# 45   gAeD3MTGCCv8YNTaK   weaklyConnected             444          64
# 15   9jPK8KBWzjFmBx4Hb             prop5             423          65
# 3    9jPK8KBWzjFmBx4Hb            prop12             408          37
# 83   YH3ANm7Y5Qe5dSYem             inv14             404          41
# 16   9jPK8KBWzjFmBx4Hb             prop6             386         119
# 81   YH3ANm7Y5Qe5dSYem             inv12             383          41
# 96   zoEADeCW2b2suJB2k              inv4             377          54
# 1    9jPK8KBWzjFmBx4Hb            prop10             348          53
# 102  zRAn69AocpkmxXZnW             inv11             339          73
# 18   9jPK8KBWzjFmBx4Hb             prop8             336          57
# 71   sDLK7uBCbgZon3znd              inv7             335         138
# 114  zRAn69AocpkmxXZnW              inv9             335         103
# 95   zoEADeCW2b2suJB2k              inv3             314          90
# 44   gAeD3MTGCCv8YNTaK        undirected             307         176
# 101  zRAn69AocpkmxXZnW             inv10             297         105
# 64   sDLK7uBCbgZon3znd              inv1             286         261
# 110  zRAn69AocpkmxXZnW              inv5             273         114
# 59   PQAJE67kz8w5NWJuM              inv5             265         121
# 105  zRAn69AocpkmxXZnW             inv14             262          38
# 70   sDLK7uBCbgZon3znd              inv6             260         146
# 112  zRAn69AocpkmxXZnW              inv7             253         116
# 60   PQAJE67kz8w5NWJuM              inv6             252         136
# 61   PQAJE67kz8w5NWJuM              inv7             247         102
# 9    9jPK8KBWzjFmBx4Hb            prop18             241          46
# 49   JC8Tij8o8GZb99gEJ              Inv4             240           1
# 39   gAeD3MTGCCv8YNTaK          complete             238         116
# 87   YH3ANm7Y5Qe5dSYem              inv4             237         126
# 97   zoEADeCW2b2suJB2k              inv5             237          50
# 14   9jPK8KBWzjFmBx4Hb             prop4             235         108
# 109  zRAn69AocpkmxXZnW              inv4             234         134
# 11   9jPK8KBWzjFmBx4Hb             prop2             227          83
# 88   YH3ANm7Y5Qe5dSYem              inv5             222         116
# 54   PQAJE67kz8w5NWJuM              inv1             218         205
# 2    9jPK8KBWzjFmBx4Hb            prop11             216          82
# 55   PQAJE67kz8w5NWJuM             inv10             216         109
# 111  zRAn69AocpkmxXZnW              inv6             215         124
# 93   zoEADeCW2b2suJB2k              inv1             212         130
# 99   zoEADeCW2b2suJB2k              inv7             209           8
# 86   YH3ANm7Y5Qe5dSYem              inv3             208         152
# 100  zRAn69AocpkmxXZnW              inv1             208         190
# 41   gAeD3MTGCCv8YNTaK          oriented             208         119
# 78   YH3ANm7Y5Qe5dSYem              inv1             200         189
# 65   sDLK7uBCbgZon3znd             inv10             199         109
# 106  zRAn69AocpkmxXZnW             inv15             199          44
# 38   gAeD3MTGCCv8YNTaK           acyclic             198         111
# 63   PQAJE67kz8w5NWJuM              inv9             198         116
# 113  zRAn69AocpkmxXZnW              inv8             198         117
# 58   PQAJE67kz8w5NWJuM              inv4             194         127
# 68   sDLK7uBCbgZon3znd              inv4             193         154
# 69   sDLK7uBCbgZon3znd              inv5             190         150
# 42   gAeD3MTGCCv8YNTaK  stonglyConnected             189          81
# 31   FwCGymHmbqcziisH5             prop3             188          38
# 82   YH3ANm7Y5Qe5dSYem             inv13             188          83
# 92   YH3ANm7Y5Qe5dSYem              inv9             187         104
# 103  zRAn69AocpkmxXZnW             inv12             184          63
# 66   sDLK7uBCbgZon3znd              inv2             182         162
# 19   9jPK8KBWzjFmBx4Hb             prop9             179          89
# 40   gAeD3MTGCCv8YNTaK           noLoops             173         107
# 91   YH3ANm7Y5Qe5dSYem              inv8             165         115
# 5    9jPK8KBWzjFmBx4Hb            prop14             162          67
# 72   sDLK7uBCbgZon3znd              inv8             162         152
# 108  zRAn69AocpkmxXZnW              inv3             162         117
# 67   sDLK7uBCbgZon3znd              inv3             161         151
# 48   JC8Tij8o8GZb99gEJ              Inv3             161          22
# 73   sDLK7uBCbgZon3znd              inv9             159         132
# 104  zRAn69AocpkmxXZnW             inv13             158          84
# 77   WGdhwKZnCu7aKhXq9              Inv4             157          18
# 79   YH3ANm7Y5Qe5dSYem             inv10             154         124
# 56   PQAJE67kz8w5NWJuM              inv2             153         123
# 17   9jPK8KBWzjFmBx4Hb             prop7             151          97
# 0    9jPK8KBWzjFmBx4Hb             prop1             149         124
# 57   PQAJE67kz8w5NWJuM              inv3             149         117
# 8    9jPK8KBWzjFmBx4Hb            prop17             148          48
# 7    9jPK8KBWzjFmBx4Hb            prop16             147          51
# 53   jyS8Bmceejj9pLbTW              Inv4             147          35
# 89   YH3ANm7Y5Qe5dSYem              inv6             146         113
# 51   jyS8Bmceejj9pLbTW              Inv2             144          51
# 84   YH3ANm7Y5Qe5dSYem             inv15             143          32
# 94   zoEADeCW2b2suJB2k              inv2             139         103
# 62   PQAJE67kz8w5NWJuM              inv8             137         133
# 90   YH3ANm7Y5Qe5dSYem              inv7             136         101
# 85   YH3ANm7Y5Qe5dSYem              inv2             134         129
# 46   JC8Tij8o8GZb99gEJ              Inv1             133          61
# 12   9jPK8KBWzjFmBx4Hb            prop20             132          53
# 47   JC8Tij8o8GZb99gEJ              Inv2             127          43
# 33   FwCGymHmbqcziisH5             prop5             124           1
# 107  zRAn69AocpkmxXZnW              inv2             122         113
# 4    9jPK8KBWzjFmBx4Hb            prop13             121          82
# 50   jyS8Bmceejj9pLbTW              Inv1             117          70
# 13   9jPK8KBWzjFmBx4Hb             prop3             112         100
# 10   9jPK8KBWzjFmBx4Hb            prop19             110          45
# 30   FwCGymHmbqcziisH5             prop2             106          41
# 6    9jPK8KBWzjFmBx4Hb            prop15             101          50
# 98   zoEADeCW2b2suJB2k              inv6             100          70
# 43   gAeD3MTGCCv8YNTaK        transitive              95          71
# 20   FwCGymHmbqcziisH5             prop1              92          46
# 32   FwCGymHmbqcziisH5             prop4              90          29
# 52   jyS8Bmceejj9pLbTW              Inv3              86          57
# 34   FwCGymHmbqcziisH5             prop6              84           4
# 37   FwCGymHmbqcziisH5             prop9              84           1
# 76   WGdhwKZnCu7aKhXq9              Inv3              57          11
# 75   WGdhwKZnCu7aKhXq9              Inv2              45          19
# 35   FwCGymHmbqcziisH5             prop7              43           9
# 26   FwCGymHmbqcziisH5            prop15              36           4
# 36   FwCGymHmbqcziisH5             prop8              35           3
# 74   WGdhwKZnCu7aKhXq9              Inv1              29          20
# 25   FwCGymHmbqcziisH5            prop14              28           1
# 22   FwCGymHmbqcziisH5            prop11              25           8
# 28   FwCGymHmbqcziisH5            prop17              16           1
# 24   FwCGymHmbqcziisH5            prop13              14           3
# 21   FwCGymHmbqcziisH5            prop10              13          10
# 27   FwCGymHmbqcziisH5            prop16               9           2
# 23   FwCGymHmbqcziisH5            prop12               2           1
# 29   FwCGymHmbqcziisH5            prop18               2           1
#
#      NumIncorrect
# 80            464
# 45            380
# 15            358
# 3             371
# 83            363
# 16            267
# 81            342
# 96            323
# 1             295
# 102           266
# 18            279
# 71            197
# 114           232
# 95            224
# 44            131
# 101           192
# 64             25
# 110           159
# 59            144
# 105           224
# 70            114
# 112           137
# 60            116
# 61            145
# 9             195
# 49            239
# 39            122
# 87            111
# 97            187
# 14            127
# 109           100
# 11            144
# 88            106
# 54             13
# 2             134
# 55            107
# 111            91
# 93             82
# 99            201
# 86             56
# 100            18
# 41             89
# 78             11
# 65             90
# 106           155
# 38             87
# 63             82
# 113            81
# 58             67
# 68             39
# 69             40
# 42            108
# 31            150
# 82            105
# 92             83
# 103           121
# 66             20
# 19             90
# 40             66
# 91             50
# 5              95
# 72             10
# 108            45
# 67             10
# 48            139
# 73             27
# 104            74
# 77            139
# 79             30
# 56             30
# 17             54
# 0              25
# 57             32
# 8             100
# 7              96
# 53            112
# 89             33
# 51             93
# 84            111
# 94             36
# 62              4
# 90             35
# 85              5
# 46             72
# 12             79
# 47             84
# 33            123
# 107             9
# 4              39
# 50             47
# 13             12
# 10             65
# 30             65
# 6              51
# 98             30
# 43             24
# 20             46
# 32             61
# 52             29
# 34             80
# 37             83
# 76             46
# 75             26
# 35             34
# 26             32
# 36             32
# 74              9
# 25             27
# 22             17
# 28             15
# 24             11
# 21              3
# 27              7
# 23              1
# 29              1

# %% [markdown]
# ## Analyze test data

# %%
analyzeData(testDfs)
# Out:
# Total number of submissions: 2059
# Total number of correct submissions: 716
# Total number of incorrect submissions: 1343
#             Challenge         Predicate  NumSubmissions  NumCorrect  \
# 47  YH3ANm7Y5Qe5dSYem             inv14             103          12
# 60  zoEADeCW2b2suJB2k              inv4             101          10
# 29  PQAJE67kz8w5NWJuM              inv7              79          22
# 70  zRAn69AocpkmxXZnW             inv15              78           1
# 12  gAeD3MTGCCv8YNTaK        undirected              70          17
# 44  YH3ANm7Y5Qe5dSYem             inv11              60          13
# 55  YH3ANm7Y5Qe5dSYem              inv8              57          18
# 13  gAeD3MTGCCv8YNTaK   weaklyConnected              57           8
# 28  PQAJE67kz8w5NWJuM              inv6              56          11
# 48  YH3ANm7Y5Qe5dSYem             inv15              55           4
# 17  JC8Tij8o8GZb99gEJ              Inv4              53           0
# 7   gAeD3MTGCCv8YNTaK          complete              50          15
# 59  zoEADeCW2b2suJB2k              inv3              41           9
# 9   gAeD3MTGCCv8YNTaK          oriented              40          17
# 31  PQAJE67kz8w5NWJuM              inv9              40          14
# 11  gAeD3MTGCCv8YNTaK        transitive              38          13
# 37  sDLK7uBCbgZon3znd              inv5              38          12
# 39  sDLK7uBCbgZon3znd              inv7              37          16
# 73  zRAn69AocpkmxXZnW              inv4              37          11
# 27  PQAJE67kz8w5NWJuM              inv5              34          18
# 66  zRAn69AocpkmxXZnW             inv11              34           7
# 45  YH3ANm7Y5Qe5dSYem             inv12              33          16
# 56  YH3ANm7Y5Qe5dSYem              inv9              33          17
# 52  YH3ANm7Y5Qe5dSYem              inv5              32          14
# 65  zRAn69AocpkmxXZnW             inv10              32           8
# 23  PQAJE67kz8w5NWJuM             inv10              31          13
# 16  JC8Tij8o8GZb99gEJ              Inv3              28           3
# 67  zRAn69AocpkmxXZnW             inv12              25           4
# 68  zRAn69AocpkmxXZnW             inv13              25           6
# 26  PQAJE67kz8w5NWJuM              inv4              25          18
# 63  zoEADeCW2b2suJB2k              inv7              23           3
# 41  sDLK7uBCbgZon3znd              inv9              23          18
# 24  PQAJE67kz8w5NWJuM              inv2              22          11
# 38  sDLK7uBCbgZon3znd              inv6              22          17
# 61  zoEADeCW2b2suJB2k              inv5              21           6
# 78  zRAn69AocpkmxXZnW              inv9              21           7
# 8   gAeD3MTGCCv8YNTaK           noLoops              21           8
# 32  sDLK7uBCbgZon3znd              inv1              20          11
# 75  zRAn69AocpkmxXZnW              inv6              19           8
# 33  sDLK7uBCbgZon3znd             inv10              19          15
# 72  zRAn69AocpkmxXZnW              inv3              19          13
# 46  YH3ANm7Y5Qe5dSYem             inv13              18           8
# 77  zRAn69AocpkmxXZnW              inv8              18           5
# 74  zRAn69AocpkmxXZnW              inv5              18          10
# 43  YH3ANm7Y5Qe5dSYem             inv10              18          10
# 50  YH3ANm7Y5Qe5dSYem              inv3              18          13
# 54  YH3ANm7Y5Qe5dSYem              inv7              17          13
# 69  zRAn69AocpkmxXZnW             inv14              17           2
# 22  PQAJE67kz8w5NWJuM              inv1              17           9
# 6   gAeD3MTGCCv8YNTaK           acyclic              17          12
# 21  jyS8Bmceejj9pLbTW              Inv4              16           5
# 36  sDLK7uBCbgZon3znd              inv4              16          13
# 76  zRAn69AocpkmxXZnW              inv7              16           9
# 51  YH3ANm7Y5Qe5dSYem              inv4              15          12
# 15  JC8Tij8o8GZb99gEJ              Inv2              13           8
# 10  gAeD3MTGCCv8YNTaK  stonglyConnected              13           8
# 57  zoEADeCW2b2suJB2k              inv1              13           7
# 25  PQAJE67kz8w5NWJuM              inv3              13          10
# 14  JC8Tij8o8GZb99gEJ              Inv1              12           8
# 40  sDLK7uBCbgZon3znd              inv8              12          12
# 53  YH3ANm7Y5Qe5dSYem              inv6              11          10
# 30  PQAJE67kz8w5NWJuM              inv8              11           8
# 62  zoEADeCW2b2suJB2k              inv6              10           7
# 64  zRAn69AocpkmxXZnW              inv1              10           8
# 58  zoEADeCW2b2suJB2k              inv2              10           5
# 42  YH3ANm7Y5Qe5dSYem              inv1               8           5
# 34  sDLK7uBCbgZon3znd              inv2               8           5
# 19  jyS8Bmceejj9pLbTW              Inv2               6           4
# 20  jyS8Bmceejj9pLbTW              Inv3               6           4
# 49  YH3ANm7Y5Qe5dSYem              inv2               6           6
# 71  zRAn69AocpkmxXZnW              inv2               6           5
# 18  jyS8Bmceejj9pLbTW              Inv1               5           4
# 35  sDLK7uBCbgZon3znd              inv3               4           4
# 0   9jPK8KBWzjFmBx4Hb             prop1               3           1
# 3   9jPK8KBWzjFmBx4Hb            prop20               2           1
# 2   9jPK8KBWzjFmBx4Hb            prop12               1           0
# 1   9jPK8KBWzjFmBx4Hb            prop10               1           1
# 5   9jPK8KBWzjFmBx4Hb             prop5               1           0
# 4   9jPK8KBWzjFmBx4Hb             prop4               1           0
#
#     NumIncorrect
# 47            91
# 60            91
# 29            57
# 70            77
# 12            53
# 44            47
# 55            39
# 13            49
# 28            45
# 48            51
# 17            53
# 7             35
# 59            32
# 9             23
# 31            26
# 11            25
# 37            26
# 39            21
# 73            26
# 27            16
# 66            27
# 45            17
# 56            16
# 52            18
# 65            24
# 23            18
# 16            25
# 67            21
# 68            19
# 26             7
# 63            20
# 41             5
# 24            11
# 38             5
# 61            15
# 78            14
# 8             13
# 32             9
# 75            11
# 33             4
# 72             6
# 46            10
# 77            13
# 74             8
# 43             8
# 50             5
# 54             4
# 69            15
# 22             8
# 6              5
# 21            11
# 36             3
# 76             7
# 51             3
# 15             5
# 10             5
# 57             6
# 25             3
# 14             4
# 40             0
# 53             1
# 30             3
# 62             3
# 64             2
# 58             5
# 42             3
# 34             3
# 19             2
# 20             2
# 49             0
# 71             1
# 18             1
# 35             0
# 0              2
# 3              1
# 2              1
# 1              0
# 5              1
# 4              1

# %% [markdown]
# # Graph Analysis

# %%
def importGraphAnalytics(path):
    return pd.read_csv(path)

def analyzeGraphAnalytics(df):
    total_submissions = 0
    total_correct = 0
    total_incorrect = 0
    total_edges = 0

    for index, row in df.iterrows():
        total_submissions += row["NumSubmissions"]
        total_correct += row["NumCorrect"]
        total_incorrect += row["NumIncorrect"]
        total_edges += row["NumEdges"]

    print("Total number of submissions: " + str(total_submissions))
    print("Total number of correct submissions: " + str(total_correct))
    print("Total number of incorrect submissions: " + str(total_incorrect))
    print("Total number of edges: " + str(total_edges))

PATH = "../../higena/src/test/outputs/"

# %%
df = importGraphAnalytics(PATH + "graph_statistics.csv")
analyzeGraphAnalytics(df)
# Out:
# Total number of submissions: 7745
# Total number of correct submissions: 991
# Total number of incorrect submissions: 6754
# Total number of edges: 11832

# %%
df
# Out:
#              Challenge         Predicate  NumSubmissions  NumCorrect  \
# 0    jyS8Bmceejj9pLbTW              Inv1              30           7
# 1    jyS8Bmceejj9pLbTW              Inv2              55           7
# 2    jyS8Bmceejj9pLbTW              Inv3              39          14
# 3    jyS8Bmceejj9pLbTW              Inv4              95          18
# 4    PQAJE67kz8w5NWJuM              inv1              24          14
# 5    PQAJE67kz8w5NWJuM              inv2              20           5
# 6    PQAJE67kz8w5NWJuM              inv3              27           6
# 7    PQAJE67kz8w5NWJuM              inv4              39          13
# 8    PQAJE67kz8w5NWJuM              inv5              75           9
# 9    PQAJE67kz8w5NWJuM              inv6              58          11
# 10   PQAJE67kz8w5NWJuM              inv7              86          19
# 11   PQAJE67kz8w5NWJuM              inv8              14          11
# 12   PQAJE67kz8w5NWJuM              inv9              75          17
# 13   PQAJE67kz8w5NWJuM             inv10              77          13
# 14   FwCGymHmbqcziisH5             prop1              45           7
# 15   FwCGymHmbqcziisH5             prop2              35           4
# 16   FwCGymHmbqcziisH5             prop3             117           7
# 17   FwCGymHmbqcziisH5             prop4              44           8
# 18   FwCGymHmbqcziisH5             prop5              87           1
# 19   FwCGymHmbqcziisH5             prop6              59           3
# 20   FwCGymHmbqcziisH5             prop7              30           4
# 21   FwCGymHmbqcziisH5             prop8              30           3
# 22   FwCGymHmbqcziisH5             prop9              68           1
# 23   FwCGymHmbqcziisH5            prop10               9           6
# 24   FwCGymHmbqcziisH5            prop11              14           3
# 25   FwCGymHmbqcziisH5            prop12               2           1
# 26   FwCGymHmbqcziisH5            prop13              11           3
# 27   FwCGymHmbqcziisH5            prop14              22           1
# 28   FwCGymHmbqcziisH5            prop15              30           4
# 29   FwCGymHmbqcziisH5            prop16               7           2
# 30   FwCGymHmbqcziisH5            prop17              14           1
# 31   FwCGymHmbqcziisH5            prop18               2           1
# 32   zRAn69AocpkmxXZnW              inv1              13           6
# 33   zRAn69AocpkmxXZnW              inv2              13           6
# 34   zRAn69AocpkmxXZnW              inv3              39          12
# 35   zRAn69AocpkmxXZnW              inv4              68          14
# 36   zRAn69AocpkmxXZnW              inv5              83          10
# 37   zRAn69AocpkmxXZnW              inv6              61          12
# 38   zRAn69AocpkmxXZnW              inv7              78          17
# 39   zRAn69AocpkmxXZnW              inv8              58          12
# 40   zRAn69AocpkmxXZnW              inv9             118          21
# 41   zRAn69AocpkmxXZnW             inv10             125          15
# 42   zRAn69AocpkmxXZnW             inv11             184          17
# 43   zRAn69AocpkmxXZnW             inv12              94          12
# 44   zRAn69AocpkmxXZnW             inv13              77          18
# 45   zRAn69AocpkmxXZnW             inv14             153          10
# 46   zRAn69AocpkmxXZnW             inv15              86           5
# 47   YH3ANm7Y5Qe5dSYem              inv1              13           4
# 48   YH3ANm7Y5Qe5dSYem              inv2               8           4
# 49   YH3ANm7Y5Qe5dSYem              inv3              39          18
# 50   YH3ANm7Y5Qe5dSYem              inv4              49          10
# 51   YH3ANm7Y5Qe5dSYem              inv5              80          12
# 52   YH3ANm7Y5Qe5dSYem              inv6              28           8
# 53   YH3ANm7Y5Qe5dSYem              inv7              28          10
# 54   YH3ANm7Y5Qe5dSYem              inv8              45          11
# 55   YH3ANm7Y5Qe5dSYem              inv9              60          12
# 56   YH3ANm7Y5Qe5dSYem             inv10              28           5
# 57   YH3ANm7Y5Qe5dSYem             inv11             219          10
# 58   YH3ANm7Y5Qe5dSYem             inv12             172           6
# 59   YH3ANm7Y5Qe5dSYem             inv13              78           5
# 60   YH3ANm7Y5Qe5dSYem             inv14             216          10
# 61   YH3ANm7Y5Qe5dSYem             inv15              82           5
# 62   9jPK8KBWzjFmBx4Hb             prop1              30          15
# 63   9jPK8KBWzjFmBx4Hb             prop2              60           4
# 64   9jPK8KBWzjFmBx4Hb             prop3               7           2
# 65   9jPK8KBWzjFmBx4Hb             prop4              56           4
# 66   9jPK8KBWzjFmBx4Hb             prop5             180           8
# 67   9jPK8KBWzjFmBx4Hb             prop6             143          13
# 68   9jPK8KBWzjFmBx4Hb             prop7              28           5
# 69   9jPK8KBWzjFmBx4Hb             prop8             135           4
# 70   9jPK8KBWzjFmBx4Hb             prop9              51           6
# 71   9jPK8KBWzjFmBx4Hb            prop10             105           2
# 72   9jPK8KBWzjFmBx4Hb            prop11              93           8
# 73   9jPK8KBWzjFmBx4Hb            prop12             238           6
# 74   9jPK8KBWzjFmBx4Hb            prop13              48          14
# 75   9jPK8KBWzjFmBx4Hb            prop14              82          13
# 76   9jPK8KBWzjFmBx4Hb            prop15              25           2
# 77   9jPK8KBWzjFmBx4Hb            prop16              65           5
# 78   9jPK8KBWzjFmBx4Hb            prop17              97          10
# 79   9jPK8KBWzjFmBx4Hb            prop18             125           4
# 80   9jPK8KBWzjFmBx4Hb            prop19              44           2
# 81   9jPK8KBWzjFmBx4Hb            prop20              42           4
# 82   sDLK7uBCbgZon3znd              inv1              25          10
# 83   sDLK7uBCbgZon3znd              inv2              16           5
# 84   sDLK7uBCbgZon3znd              inv3              12           4
# 85   sDLK7uBCbgZon3znd              inv4              25           8
# 86   sDLK7uBCbgZon3znd              inv5              29           9
# 87   sDLK7uBCbgZon3znd              inv6              67           9
# 88   sDLK7uBCbgZon3znd              inv7              80          13
# 89   sDLK7uBCbgZon3znd              inv8              25          17
# 90   sDLK7uBCbgZon3znd              inv9              42          23
# 91   sDLK7uBCbgZon3znd             inv10              60          12
# 92   WGdhwKZnCu7aKhXq9              Inv1              14           6
# 93   WGdhwKZnCu7aKhXq9              Inv2              32           9
# 94   WGdhwKZnCu7aKhXq9              Inv3              42           5
# 95   WGdhwKZnCu7aKhXq9              Inv4              90           8
# 96   gAeD3MTGCCv8YNTaK        undirected              96          21
# 97   gAeD3MTGCCv8YNTaK          oriented              71          19
# 98   gAeD3MTGCCv8YNTaK           acyclic              71          10
# 99   gAeD3MTGCCv8YNTaK          complete              78          15
# 100  gAeD3MTGCCv8YNTaK           noLoops              46          12
# 101  gAeD3MTGCCv8YNTaK   weaklyConnected             215          13
# 102  gAeD3MTGCCv8YNTaK  stonglyConnected              62          12
# 103  gAeD3MTGCCv8YNTaK        transitive              29          11
# 104  JC8Tij8o8GZb99gEJ              Inv1              50           9
# 105  JC8Tij8o8GZb99gEJ              Inv2              74          13
# 106  JC8Tij8o8GZb99gEJ              Inv3              98           9
# 107  JC8Tij8o8GZb99gEJ              Inv4             152           1
# 108  zoEADeCW2b2suJB2k              inv1              40           8
# 109  zoEADeCW2b2suJB2k              inv2              28           3
# 110  zoEADeCW2b2suJB2k              inv3             107          11
# 111  zoEADeCW2b2suJB2k              inv4             219          15
# 112  zoEADeCW2b2suJB2k              inv5             124           9
# 113  zoEADeCW2b2suJB2k              inv6              37          16
# 114  zoEADeCW2b2suJB2k              inv7             138           6
#
#      NumIncorrect  NumEdges
# 0              23        48
# 1              48        75
# 2              25        49
# 3              77       115
# 4              10        43
# 5              15        38
# 6              21        42
# 7              26        68
# 8              66       143
# 9              47       111
# 10             67       148
# 11              3        23
# 12             58       101
# 13             64       131
# 14             38        58
# 15             31        60
# 16            110       160
# 17             36        63
# 18             86       100
# 19             56        72
# 20             26        35
# 21             27        29
# 22             67        78
# 23              3        10
# 24             11        21
# 25              1         1
# 26              8        12
# 27             21        25
# 28             26        33
# 29              5         7
# 30             13        15
# 31              1         1
# 32              7        30
# 33              7        17
# 34             27        60
# 35             54       120
# 36             73       147
# 37             49       106
# 38             61       136
# 39             46        92
# 40             97       192
# 41            110       197
# 42            167       254
# 43             82       130
# 44             59       102
# 45            143       182
# 46             81       139
# 47              9        23
# 48              4        11
# 49             21        69
# 50             39        93
# 51             68       134
# 52             20        52
# 53             18        42
# 54             34        69
# 55             48        93
# 56             23        46
# 57            209       366
# 58            166       266
# 59             73       110
# 60            206       297
# 61             77       105
# 62             15        46
# 63             56       134
# 64              5        10
# 65             52       109
# 66            172       305
# 67            130       262
# 68             23        51
# 69            131       238
# 70             45        88
# 71            103       221
# 72             85       143
# 73            232       348
# 74             34        67
# 75             69       115
# 76             23        45
# 77             60        98
# 78             87       120
# 79            121       193
# 80             42        65
# 81             38        75
# 82             15        40
# 83             11        25
# 84              8        18
# 85             17        46
# 86             20        50
# 87             58       117
# 88             67       162
# 89              8        36
# 90             19        58
# 91             48        96
# 92              8        18
# 93             23        34
# 94             37        49
# 95             82       116
# 96             75       159
# 97             52       109
# 98             61       111
# 99             63       141
# 100            34        84
# 101           202       346
# 102            50       108
# 103            18        41
# 104            41        81
# 105            61        88
# 106            89       123
# 107           151       202
# 108            32        74
# 109            25        42
# 110            96       185
# 111           204       295
# 112           115       175
# 113            21        56
# 114           132       179

# %% [markdown]
# # Hint Analysis

# %% [markdown]
# ## Normal

# %% [markdown]
# Import data.

# %%
df = pd.read_json(PATH + "hints_statistics.json", lines=True)
total_hints = len(df)

# %% [markdown]
# Analyze number of new nodes in the graph.

# %%
count = df["isNewNode"].value_counts()
print("Total number of hints: " + str(total_hints))
print("Number of old submissions: " + str(count[1]) + " (" + str(round(count[1] / total_hints * 100, 2)) + "%)")
print("Number of new submissions: " + str(count[0]) + " (" + str(round(count[0] / total_hints * 100, 2)) + "%)")
# Out:
# Total number of hints: 1343
# Number of old submissions: 325 (24.2%)
# Number of new submissions: 1018 (75.8%)

# %%
count = df["createdShorterPath"].value_counts()
print("Total number of hints: " + str(total_hints))
print("Number of old submissions: " + str(count[1]) + " (" + str(round(count[1] / total_hints * 100, 2)) + "%)")
print("Number of new submissions: " + str(count[0]) + " (" + str(round(count[0] / total_hints * 100, 2)) + "%)")
# Out:
# Total number of hints: 1343
# Number of old submissions: 90 (6.7%)
# Number of new submissions: 1253 (93.3%)

# %% [markdown]
# ## No new paths
#
# Not creating new path when TED too long.

# %% [markdown]
# Import data.

# %%
df = pd.read_json(PATH + "bad_paths_hints_statistics.json", lines=True)
total_hints = len(df)

# %% [markdown]
# Analyze distances.

# %%
longer_paths = df[df["srcDstTED"] < df["totalTED"]]
equal_paths = df[df["srcDstTED"] == df["totalTED"]]
num_longer_paths = len(longer_paths)
num_equal_paths = len(equal_paths)

print("Total number of hints: " + str(total_hints))
print("Number of hints with longer paths: " + str(num_longer_paths) + " (" + str(round(num_longer_paths / total_hints * 100, 2)) + "%)")
print("Number of hints with equal paths: " + str(num_equal_paths) + " (" + str(round(num_equal_paths / total_hints * 100, 2)) + "%)")
# Out:
# Total number of hints: 1343
# Number of hints with longer paths: 90 (6.7%)
# Number of hints with equal paths: 1253 (93.3%)

# %% [markdown]
# ## No branch swap
#
# Not swapping branches for commutative operations with common branches.

# %%
df = pd.read_json(PATH + "no_swap_hints_statistics.json", lines=True)
total_hints = len(df)

# %% [markdown]
# ## GumTree Mapping
#
# Using gumtree mapping instead of apted.

# %%
gumtree_df = pd.read_json(PATH + "gumtree_hints_statistics.json", lines=True)
total_hints = len(gumtree_df)

# %% [markdown]
# Check which actions are different.

# %%
# TODO
